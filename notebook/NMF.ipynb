# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scipy.sparse as sp
from time import time
from sklearn.metrics import mean_squared_error
from sklearn.metrics.pairwise import pairwise_distances
from scipy.stats.stats import pearsonr
import graphlab
from sklearn.cross_validation import train_test_split
from math import sqrt
import scipy.sparse as sp
from scipy.sparse.linalg import svds
# %matplotlib inline
import numpy as np
import pandas as pd

from nltk.corpus import stopwords
from nltk.tokenize import RegexpTokenizer
from nltk.stem.porter import PorterStemmer

from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.decomposition import NMF as nmf

# %%
def build_text_vectorizer(contents, use_tfidf=True, use_stemmer=False, max_features=None):
    '''
    Build and return a **callable** for transforming text documents to vectors,
    as well as a vocabulary to map document-vector indices to words from the
    corpus. The vectorizer will be trained from the text documents in the
    `contents` argument. If `use_tfidf` is True, then the vectorizer will use
    the Tf-Idf algorithm, otherwise a Bag-of-Words vectorizer will be used.
    The text will be tokenized by words, and each word will be stemmed iff
    `use_stemmer` is True. If `max_features` is not None, then the vocabulary
    will be limited to the `max_features` most common words in the corpus.
    '''
    Vectorizer = TfidfVectorizer if use_tfidf else CountVectorizer
    tokenizer = RegexpTokenizer(r"[\w']+")
    stem = PorterStemmer().stem if use_stemmer else (lambda x: x)
    stop_set = set(stopwords.words('english'))

    # Closure over the tokenizer et al.
    def tokenize(text):
        tokens = tokenizer.tokenize(text)
        stems = [stem(token) for token in tokens if token not in stop_set]
        return stems

    vectorizer_model = Vectorizer(tokenizer=tokenize, max_features=max_features)
    vectorizer_model.fit(contents)
    vocabulary = np.array(vectorizer_model.get_feature_names())

    # Closure over the vectorizer_model's transform method.
    def vectorizer(X):
        return vectorizer_model.transform(X).toarray()

    return vectorizer, vocabulary

# %%
df = pd.read_csv("processed_data.csv")

# %%
df = df[df["user_review_count"] > 2]

# %%
df.shape
# Out:
# (47583, 36)

# %%
title = df.published_title.tolist()

# %%
vectorizer, vocabulary = build_text_vectorizer(title,
                             use_tfidf=True,
                             use_stemmer=False,
                             max_features=5000)
X = vectorizer(title)

# %%
nmf = nmf(n_components=15, max_iter=100, random_state=12345, alpha=0.0)
W = nmf.fit_transform(X)
H = nmf.components_
print 'reconstruction error:', nmf.reconstruction_err_
# Out:
# reconstruction error: 180.577482053

# %%
def hand_label_topics(H, vocabulary):
    '''
    Print the most influential words of each latent topic, and prompt the user
    to label each topic. The user should use their humanness to figure out what
    each latent topic is capturing.
    '''
    hand_labels = []
    for i, row in enumerate(H):
        top_five = np.argsort(row)[::-1][:20]
        print 'topic', i
        print '-->', ' '.join(vocabulary[top_five])
        label = raw_input('please label this topic: ')
        hand_labels.append(label)
        print
    return hand_labels

# %%
hand_labels = hand_label_topics(H, vocabulary)
# Out:
# topic 0
# --> web developer 2 bootcamp course become job scratch modern workflow mastering ready stack django git full services development certified master
# please label this topic: web development
#
# topic 1
# --> javascript understand es6 scratch 2016 jquery answers interview top questions next generation learn complete fast easy tutorial basics hour introduction
# please label this topic: javascript
#
# topic 2
# --> 2 angular guide complete practical vuejs developers webpack nodejs mongodb ultimate apps beginners building ionic photography inventory drop shipping ebay
# please label this topic: angular
#
# topic 3
# --> react redux native tutorial meteor graphql flux complete js advanced apps mastering router web node fullstack express universal ansible workflow
# please label this topic: react redux
#
# topic 4
# --> learn angularjs code jumpstart scratch days linux marketing 5 digital building development hacking ethical android 10 programming projects jquery game
# please label this topic: mobile apps
#
# topic 5
# --> bootcamp complete sql python 2016 administration newbs linux next generation phoenix elixir es6 go oracle javascript expert beginner mysql continuous
# please label this topic: sql, python, linux programming
#
# topic 6
# --> course complete developer 2 aspnet mvc 5 security ios 10 native wordpress rails javascript ruby certification python android 1 privacy
# please label this topic: wordpress, rails, javascript, ruby
#
# topic 7
# --> tutorial beginners csharp es6 spring hibernate php angular framework entity jsp oriented object msql includes wordpress 2 javascript meteor programming
# please label this topic: csharp, php
#
# topic 8
# --> nodejs understand practical 2 developer projects building 10 learn algorithms data themes offensive structures list copy paste subtitle 12c macros
# please label this topic: nodejs
#
# topic 9
# --> certified aws associate solutions architect developer sysops administrator become tests practice exam enterprise togaf security se prepare hacking beginner 8
# please label this topic: aws, information technology
#
# topic 10
# --> design website html5 css3 develop killer wordpress business build bootstrap scratch graphic mastering master object oriented responsive user experience home
# please label this topic: web design - html, css, wordpress
#
# topic 11
# --> unitycourse ultimate google adwords training certification excel programming blendertutorial programmer life reiki analytics coach animal seo r beginner microsoft comptia
# please label this topic: game modeling and animation
#
# topic 12
# --> java developer complete object oriented programming services mastering introduction step algorithms structures absolute course android php depth design engineer app
# please label this topic: java programming
#
# topic 13
# --> csharp advanced intermediate classes interfaces oop beginners excel beginner tableau10 microsoft programming 2013 beyond angular2 ultimate programing c drawing native
# please label this topic: object oriented programming, microsoft excel
#
# topic 14
# --> python data learning science machine hands analysis mega visualization bible coding r programming big complete spark django developer deep regression
# please label this topic: data science, machine learning

# %%
len(W)
# Out:
# 47583

# %%
def softmax(v, temperature=1.0):
    '''
    A heuristic to convert arbitrary positive values into probabilities.
    See: https://en.wikipedia.org/wiki/Softmax_function
    '''
    expv = np.exp(v / temperature)
    s = np.sum(expv)
    return expv / s

# %%
def analyze_article(article_index, title, W, hand_labels):
    '''
    Print an analysis of a single NYT articles, including the article text
    and a summary of which topics it represents. The topics are identified
    via the hand-labels which were assigned by the user.
    '''
    #print title[article_index]
    probs = softmax(W[article_index], temperature=0.01)
    lst = []
    for prob, label in zip(probs, hand_labels):
        lst.append((prob * 100, label))
    return max(lst)[1]

# %%
analyze_article(0, title, W, hand_labels)
# Out:
# 'mobile apps'

# %%
title_category = {}
for i in xrange(len(title)):
     title_category[i] = analyze_article(i, title, W, hand_labels)

# %%
title_category
# Out:
# {0: 'mobile apps',
#  1: 'mobile apps',
#  2: 'mobile apps',
#  3: 'mobile apps',
#  4: 'mobile apps',
#  5: 'mobile apps',
#  6: 'mobile apps',
#  7: 'mobile apps',
#  8: 'mobile apps',
#  9: 'mobile apps',
#  10: 'mobile apps',
#  11: 'mobile apps',
#  12: 'mobile apps',
#  13: 'mobile apps',
#  14: 'mobile apps',
#  15: 'mobile apps',
#  16: 'mobile apps',
#  17: 'mobile apps',
#  18: 'mobile apps',
#  19: 'mobile apps',
#  20: 'mobile apps',
#  21: 'mobile apps',
#  22: 'mobile apps',
#  23: 'mobile apps',
#  24: 'mobile apps',
#  25: 'mobile apps',
#  26: 'mobile apps',
#  27: 'mobile apps',
#  28: 'mobile apps',
#  29: 'mobile apps',
#  30: 'mobile apps',
#  31: 'mobile apps',
#  32: 'mobile apps',
#  33: 'mobile apps',
#  34: 'mobile apps',
#  35: 'mobile apps',
#  36: 'mobile apps',
#  37: 'mobile apps',
#  38: 'mobile apps',
#  39: 'mobile apps',
#  40: 'mobile apps',
#  41: 'mobile apps',
#  42: 'mobile apps',
#  43: 'mobile apps',
#  44: 'mobile apps',
#  45: 'mobile apps',
#  46: 'mobile apps',
#  47: 'mobile apps',
#  48: 'mobile apps',
#  49: 'mobile apps',
#  50: 'mobile apps',
#  51: 'mobile apps',
#  52: 'mobile apps',
#  53: 'mobile apps',
#  54: 'mobile apps',
#  55: 'mobile apps',
#  56: 'mobile apps',
#  57: 'mobile apps',
#  58: 'mobile apps',
#  59: 'mobile apps',
#  60: 'mobile apps',
#  61: 'mobile apps',
#  62: 'mobile apps',
#  63: 'mobile apps',
#  64: 'mobile apps',
#  65: 'mobile apps',
#  66: 'mobile apps',
#  67: 'mobile apps',
#  68: 'mobile apps',
#  69: 'mobile apps',
#  70: 'mobile apps',
#  71: 'mobile apps',
#  72: 'mobile apps',
#  73: 'mobile apps',
#  74: 'mobile apps',
#  75: 'mobile apps',
#  76: 'mobile apps',
#  77: 'mobile apps',
#  78: 'mobile apps',
#  79: 'mobile apps',
#  80: 'mobile apps',
#  81: 'mobile apps',
#  82: 'mobile apps',
#  83: 'mobile apps',
#  84: 'mobile apps',
#  85: 'mobile apps',
#  86: 'mobile apps',
#  87: 'mobile apps',
#  88: 'mobile apps',
#  89: 'mobile apps',
#  90: 'mobile apps',
#  91: 'mobile apps',
#  92: 'mobile apps',
#  93: 'mobile apps',
#  94: 'mobile apps',
#  95: 'mobile apps',
#  96: 'mobile apps',
#  97: 'mobile apps',
#  98: 'mobile apps',
#  99: 'mobile apps',
#  100: 'mobile apps',
#  101: 'mobile apps',
#  102: 'mobile apps',
#  103: 'mobile apps',
#  104: 'mobile apps',
#  105: 'mobile apps',
#  106: 'mobile apps',
#  107: 'mobile apps',
#  108: 'mobile apps',
#  109: 'mobile apps',
#  110: 'mobile apps',
#  111: 'mobile apps',
#  112: 'mobile apps',
#  113: 'mobile apps',
#  114: 'mobile apps',
#  115: 'mobile apps',
#  116: 'mobile apps',
#  117: 'mobile apps',
#  118: 'mobile apps',
#  119: 'mobile apps',
#  120: 'mobile apps',
#  121: 'mobile apps',
#  122: 'mobile apps',
#  123: 'mobile apps',
#  124: 'mobile apps',
#  125: 'mobile apps',
#  126: 'mobile apps',
#  127: 'mobile apps',
#  128: 'mobile apps',
#  129: 'mobile apps',
#  130: 'mobile apps',
#  131: 'mobile apps',
#  132: 'mobile apps',
#  133: 'mobile apps',
#  134: 'mobile apps',
#  135: 'mobile apps',
#  136: 'mobile apps',
#  137: 'mobile apps',
#  138: 'mobile apps',
#  139: 'mobile apps',
#  140: 'mobile apps',
#  141: 'mobile apps',
#  142: 'mobile apps',
#  143: 'mobile apps',
#  144: 'mobile apps',
#  145: 'mobile apps',
#  146: 'mobile apps',
#  147: 'mobile apps',
#  148: 'mobile apps',
#  149: 'mobile apps',
#  150: 'mobile apps',
#  151: 'mobile apps',
#  152: 'mobile apps',
#  153: 'mobile apps',
#  154: 'mobile apps',
#  155: 'mobile apps',
#  156: 'mobile apps',
#  157: 'mobile apps',
#  158: 'mobile apps',
#  159: 'mobile apps',
#  160: 'mobile apps',
#  161: 'mobile apps',
#  162: 'mobile apps',
#  163: 'mobile apps',
#  164: 'mobile apps',
#  165: 'mobile apps',
#  166: 'mobile apps',
#  167: 'mobile apps',
#  168: 'mobile apps',
#  169: 'mobile apps',
#  170: 'mobile apps',
#  171: 'mobile apps',
#  172: 'mobile apps',
#  173: 'mobile apps',
#  174: 'mobile apps',
#  175: 'mobile apps',
#  176: 'mobile apps',
#  177: 'mobile apps',
#  178: 'mobile apps',
#  179: 'mobile apps',
#  180: 'mobile apps',
#  181: 'mobile apps',
#  182: 'mobile apps',
#  183: 'mobile apps',
#  184: 'mobile apps',
#  185: 'mobile apps',
#  186: 'mobile apps',
#  187: 'mobile apps',
#  188: 'mobile apps',
#  189: 'mobile apps',
#  190: 'mobile apps',
#  191: 'mobile apps',
#  192: 'mobile apps',
#  193: 'mobile apps',
#  194: 'mobile apps',
#  195: 'mobile apps',
#  196: 'mobile apps',
#  197: 'mobile apps',
#  198: 'mobile apps',
#  199: 'mobile apps',
#  200: 'mobile apps',
#  201: 'mobile apps',
#  202: 'mobile apps',
#  203: 'mobile apps',
#  204: 'mobile apps',
#  205: 'mobile apps',
#  206: 'mobile apps',
#  207: 'mobile apps',
#  208: 'mobile apps',
#  209: 'mobile apps',
#  210: 'mobile apps',
#  211: 'mobile apps',
#  212: 'mobile apps',
#  213: 'mobile apps',
#  214: 'mobile apps',
#  215: 'mobile apps',
#  216: 'mobile apps',
#  217: 'mobile apps',
#  218: 'mobile apps',
#  219: 'mobile apps',
#  220: 'mobile apps',
#  221: 'mobile apps',
#  222: 'mobile apps',
#  223: 'mobile apps',
#  224: 'mobile apps',
#  225: 'mobile apps',
#  226: 'mobile apps',
#  227: 'mobile apps',
#  228: 'mobile apps',
#  229: 'mobile apps',
#  230: 'mobile apps',
#  231: 'mobile apps',
#  232: 'mobile apps',
#  233: 'mobile apps',
#  234: 'mobile apps',
#  235: 'mobile apps',
#  236: 'mobile apps',
#  237: 'mobile apps',
#  238: 'mobile apps',
#  239: 'mobile apps',
#  240: 'mobile apps',
#  241: 'mobile apps',
#  242: 'mobile apps',
#  243: 'mobile apps',
#  244: 'mobile apps',
#  245: 'mobile apps',
#  246: 'mobile apps',
#  247: 'mobile apps',
#  248: 'mobile apps',
#  249: 'mobile apps',
#  250: 'mobile apps',
#  251: 'mobile apps',
#  252: 'mobile apps',
#  253: 'mobile apps',
#  254: 'mobile apps',
#  255: 'mobile apps',
#  256: 'mobile apps',
#  257: 'mobile apps',
#  258: 'mobile apps',
#  259: 'mobile apps',
#  260: 'mobile apps',
#  261: 'mobile apps',
#  262: 'mobile apps',
#  263: 'mobile apps',
#  264: 'mobile apps',
#  265: 'mobile apps',
#  266: 'mobile apps',
#  267: 'mobile apps',
#  268: 'mobile apps',
#  269: 'mobile apps',
#  270: 'mobile apps',
#  271: 'mobile apps',
#  272: 'mobile apps',
#  273: 'mobile apps',
#  274: 'mobile apps',
#  275: 'mobile apps',
#  276: 'mobile apps',
#  277: 'mobile apps',
#  278: 'mobile apps',
#  279: 'mobile apps',
#  280: 'mobile apps',
#  281: 'mobile apps',
#  282: 'mobile apps',
#  283: 'mobile apps',
#  284: 'mobile apps',
#  285: 'mobile apps',
#  286: 'mobile apps',
#  287: 'mobile apps',
#  288: 'mobile apps',
#  289: 'mobile apps',
#  290: 'mobile apps',
#  291: 'mobile apps',
#  292: 'mobile apps',
#  293: 'mobile apps',
#  294: 'mobile apps',
#  295: 'mobile apps',
#  296: 'mobile apps',
#  297: 'mobile apps',
#  298: 'mobile apps',
#  299: 'mobile apps',
#  300: 'mobile apps',
#  301: 'mobile apps',
#  302: 'mobile apps',
#  303: 'mobile apps',
#  304: 'mobile apps',
#  305: 'mobile apps',
#  306: 'mobile apps',
#  307: 'mobile apps',
#  308: 'mobile apps',
#  309: 'mobile apps',
#  310: 'mobile apps',
#  311: 'mobile apps',
#  312: 'mobile apps',
#  313: 'mobile apps',
#  314: 'mobile apps',
#  315: 'mobile apps',
#  316: 'mobile apps',
#  317: 'mobile apps',
#  318: 'mobile apps',
#  319: 'mobile apps',
#  320: 'mobile apps',
#  321: 'mobile apps',
#  322: 'mobile apps',
#  323: 'mobile apps',
#  324: 'mobile apps',
#  325: 'mobile apps',
#  326: 'mobile apps',
#  327: 'mobile apps',
#  328: 'mobile apps',
#  329: 'mobile apps',
#  330: 'mobile apps',
#  331: 'mobile apps',
#  332: 'mobile apps',
#  333: 'mobile apps',
#  334: 'mobile apps',
#  335: 'mobile apps',
#  336: 'mobile apps',
#  337: 'mobile apps',
#  338: 'mobile apps',
#  339: 'mobile apps',
#  340: 'mobile apps',
#  341: 'mobile apps',
#  342: 'mobile apps',
#  343: 'mobile apps',
#  344: 'mobile apps',
#  345: 'mobile apps',
#  346: 'mobile apps',
#  347: 'mobile apps',
#  348: 'mobile apps',
#  349: 'mobile apps',
#  350: 'mobile apps',
#  351: 'mobile apps',
#  352: 'mobile apps',
#  353: 'mobile apps',
#  354: 'mobile apps',
#  355: 'mobile apps',
#  356: 'mobile apps',
#  357: 'mobile apps',
#  358: 'mobile apps',
#  359: 'mobile apps',
#  360: 'mobile apps',
#  361: 'mobile apps',
#  362: 'mobile apps',
#  363: 'mobile apps',
#  364: 'mobile apps',
#  365: 'mobile apps',
#  366: 'mobile apps',
#  367: 'mobile apps',
#  368: 'mobile apps',
#  369: 'mobile apps',
#  370: 'mobile apps',
#  371: 'mobile apps',
#  372: 'mobile apps',
#  373: 'mobile apps',
#  374: 'mobile apps',
#  375: 'mobile apps',
#  376: 'mobile apps',
#  377: 'mobile apps',
#  378: 'mobile apps',
#  379: 'mobile apps',
#  380: 'mobile apps',
#  381: 'mobile apps',
#  382: 'mobile apps',
#  383: 'mobile apps',
#  384: 'mobile apps',
#  385: 'mobile apps',
#  386: 'mobile apps',
#  387: 'mobile apps',
#  388: 'mobile apps',
#  389: 'mobile apps',
#  390: 'mobile apps',
#  391: 'mobile apps',
#  392: 'mobile apps',
#  393: 'mobile apps',
#  394: 'mobile apps',
#  395: 'mobile apps',
#  396: 'mobile apps',
#  397: 'mobile apps',
#  398: 'mobile apps',
#  399: 'mobile apps',
#  400: 'mobile apps',
#  401: 'mobile apps',
#  402: 'mobile apps',
#  403: 'mobile apps',
#  404: 'mobile apps',
#  405: 'mobile apps',
#  406: 'mobile apps',
#  407: 'mobile apps',
#  408: 'mobile apps',
#  409: 'mobile apps',
#  410: 'mobile apps',
#  411: 'mobile apps',
#  412: 'mobile apps',
#  413: 'mobile apps',
#  414: 'mobile apps',
#  415: 'mobile apps',
#  416: 'mobile apps',
#  417: 'mobile apps',
#  418: 'mobile apps',
#  419: 'mobile apps',
#  420: 'mobile apps',
#  421: 'mobile apps',
#  422: 'mobile apps',
#  423: 'mobile apps',
#  424: 'mobile apps',
#  425: 'mobile apps',
#  426: 'mobile apps',
#  427: 'mobile apps',
#  428: 'mobile apps',
#  429: 'mobile apps',
#  430: 'mobile apps',
#  431: 'mobile apps',
#  432: 'mobile apps',
#  433: 'mobile apps',
#  434: 'mobile apps',
#  435: 'mobile apps',
#  436: 'mobile apps',
#  437: 'mobile apps',
#  438: 'mobile apps',
#  439: 'mobile apps',
#  440: 'mobile apps',
#  441: 'mobile apps',
#  442: 'mobile apps',
#  443: 'mobile apps',
#  444: 'mobile apps',
#  445: 'mobile apps',
#  446: 'mobile apps',
#  447: 'mobile apps',
#  448: 'mobile apps',
#  449: 'mobile apps',
#  450: 'mobile apps',
#  451: 'mobile apps',
#  452: 'mobile apps',
#  453: 'mobile apps',
#  454: 'mobile apps',
#  455: 'mobile apps',
#  456: 'mobile apps',
#  457: 'mobile apps',
#  458: 'mobile apps',
#  459: 'mobile apps',
#  460: 'mobile apps',
#  461: 'mobile apps',
#  462: 'mobile apps',
#  463: 'mobile apps',
#  464: 'mobile apps',
#  465: 'mobile apps',
#  466: 'mobile apps',
#  467: 'mobile apps',
#  468: 'mobile apps',
#  469: 'mobile apps',
#  470: 'mobile apps',
#  471: 'mobile apps',
#  472: 'mobile apps',
#  473: 'mobile apps',
#  474: 'mobile apps',
#  475: 'mobile apps',
#  476: 'mobile apps',
#  477: 'mobile apps',
#  478: 'mobile apps',
#  479: 'mobile apps',
#  480: 'mobile apps',
#  481: 'mobile apps',
#  482: 'mobile apps',
#  483: 'mobile apps',
#  484: 'mobile apps',
#  485: 'mobile apps',
#  486: 'mobile apps',
#  487: 'mobile apps',
#  488: 'mobile apps',
#  489: 'mobile apps',
#  490: 'mobile apps',
#  491: 'mobile apps',
#  492: 'mobile apps',
#  493: 'mobile apps',
#  494: 'mobile apps',
#  495: 'mobile apps',
#  496: 'mobile apps',
#  497: 'mobile apps',
#  498: 'mobile apps',
#  499: 'mobile apps',
#  500: 'mobile apps',
#  501: 'mobile apps',
#  502: 'mobile apps',
#  503: 'mobile apps',
#  504: 'mobile apps',
#  505: 'mobile apps',
#  506: 'mobile apps',
#  507: 'mobile apps',
#  508: 'mobile apps',
#  509: 'mobile apps',
#  510: 'mobile apps',
#  511: 'mobile apps',
#  512: 'mobile apps',
#  513: 'mobile apps',
#  514: 'mobile apps',
#  515: 'mobile apps',
#  516: 'mobile apps',
#  517: 'mobile apps',
#  518: 'mobile apps',
#  519: 'mobile apps',
#  520: 'mobile apps',
#  521: 'mobile apps',
#  522: 'mobile apps',
#  523: 'mobile apps',
#  524: 'mobile apps',
#  525: 'mobile apps',
#  526: 'mobile apps',
#  527: 'mobile apps',
#  528: 'mobile apps',
#  529: 'mobile apps',
#  530: 'mobile apps',
#  531: 'mobile apps',
#  532: 'mobile apps',
#  533: 'mobile apps',
#  534: 'mobile apps',
#  535: 'mobile apps',
#  536: 'mobile apps',
#  537: 'mobile apps',
#  538: 'mobile apps',
#  539: 'mobile apps',
#  540: 'mobile apps',
#  541: 'mobile apps',
#  542: 'mobile apps',
#  543: 'mobile apps',
#  544: 'mobile apps',
#  545: 'mobile apps',
#  546: 'mobile apps',
#  547: 'mobile apps',
#  548: 'mobile apps',
#  549: 'mobile apps',
#  550: 'mobile apps',
#  551: 'mobile apps',
#  552: 'mobile apps',
#  553: 'mobile apps',
#  554: 'mobile apps',
#  555: 'mobile apps',
#  556: 'mobile apps',
#  557: 'mobile apps',
#  558: 'mobile apps',
#  559: 'mobile apps',
#  560: 'mobile apps',
#  561: 'mobile apps',
#  562: 'mobile apps',
#  563: 'mobile apps',
#  564: 'mobile apps',
#  565: 'mobile apps',
#  566: 'mobile apps',
#  567: 'mobile apps',
#  568: 'mobile apps',
#  569: 'mobile apps',
#  570: 'mobile apps',
#  571: 'mobile apps',
#  572: 'mobile apps',
#  573: 'mobile apps',
#  574: 'mobile apps',
#  575: 'mobile apps',
#  576: 'mobile apps',
#  577: 'mobile apps',
#  578: 'mobile apps',
#  579: 'mobile apps',
#  580: 'mobile apps',
#  581: 'mobile apps',
#  582: 'mobile apps',
#  583: 'mobile apps',
#  584: 'mobile apps',
#  585: 'mobile apps',
#  586: 'mobile apps',
#  587: 'mobile apps',
#  588: 'mobile apps',
#  589: 'mobile apps',
#  590: 'mobile apps',
#  591: 'mobile apps',
#  592: 'mobile apps',
#  593: 'mobile apps',
#  594: 'mobile apps',
#  595: 'mobile apps',
#  596: 'mobile apps',
#  597: 'mobile apps',
#  598: 'mobile apps',
#  599: 'mobile apps',
#  600: 'mobile apps',
#  601: 'mobile apps',
#  602: 'mobile apps',
#  603: 'mobile apps',
#  604: 'mobile apps',
#  605: 'mobile apps',
#  606: 'mobile apps',
#  607: 'mobile apps',
#  608: 'mobile apps',
#  609: 'mobile apps',
#  610: 'mobile apps',
#  611: 'mobile apps',
#  612: 'mobile apps',
#  613: 'mobile apps',
#  614: 'mobile apps',
#  615: 'mobile apps',
#  616: 'mobile apps',
#  617: 'mobile apps',
#  618: 'mobile apps',
#  619: 'mobile apps',
#  620: 'mobile apps',
#  621: 'mobile apps',
#  622: 'mobile apps',
#  623: 'mobile apps',
#  624: 'mobile apps',
#  625: 'mobile apps',
#  626: 'mobile apps',
#  627: 'mobile apps',
#  628: 'mobile apps',
#  629: 'mobile apps',
#  630: 'mobile apps',
#  631: 'mobile apps',
#  632: 'mobile apps',
#  633: 'mobile apps',
#  634: 'mobile apps',
#  635: 'mobile apps',
#  636: 'mobile apps',
#  637: 'mobile apps',
#  638: 'mobile apps',
#  639: 'mobile apps',
#  640: 'mobile apps',
#  641: 'mobile apps',
#  642: 'mobile apps',
#  643: 'mobile apps',
#  644: 'mobile apps',
#  645: 'mobile apps',
#  646: 'mobile apps',
#  647: 'mobile apps',
#  648: 'mobile apps',
#  649: 'mobile apps',
#  650: 'mobile apps',
#  651: 'mobile apps',
#  652: 'mobile apps',
#  653: 'mobile apps',
#  654: 'mobile apps',
#  655: 'mobile apps',
#  656: 'mobile apps',
#  657: 'mobile apps',
#  658: 'mobile apps',
#  659: 'mobile apps',
#  660: 'mobile apps',
#  661: 'mobile apps',
#  662: 'mobile apps',
#  663: 'mobile apps',
#  664: 'mobile apps',
#  665: 'mobile apps',
#  666: 'mobile apps',
#  667: 'mobile apps',
#  668: 'mobile apps',
#  669: 'mobile apps',
#  670: 'mobile apps',
#  671: 'mobile apps',
#  672: 'mobile apps',
#  673: 'mobile apps',
#  674: 'mobile apps',
#  675: 'mobile apps',
#  676: 'mobile apps',
#  677: 'mobile apps',
#  678: 'mobile apps',
#  679: 'mobile apps',
#  680: 'mobile apps',
#  681: 'mobile apps',
#  682: 'mobile apps',
#  683: 'mobile apps',
#  684: 'mobile apps',
#  685: 'mobile apps',
#  686: 'mobile apps',
#  687: 'mobile apps',
#  688: 'mobile apps',
#  689: 'mobile apps',
#  690: 'mobile apps',
#  691: 'mobile apps',
#  692: 'mobile apps',
#  693: 'mobile apps',
#  694: 'mobile apps',
#  695: 'mobile apps',
#  696: 'mobile apps',
#  697: 'mobile apps',
#  698: 'mobile apps',
#  699: 'mobile apps',
#  700: 'mobile apps',
#  701: 'mobile apps',
#  702: 'mobile apps',
#  703: 'mobile apps',
#  704: 'mobile apps',
#  705: 'mobile apps',
#  706: 'mobile apps',
#  707: 'mobile apps',
#  708: 'mobile apps',
#  709: 'mobile apps',
#  710: 'mobile apps',
#  711: 'mobile apps',
#  712: 'mobile apps',
#  713: 'mobile apps',
#  714: 'mobile apps',
#  715: 'mobile apps',
#  716: 'mobile apps',
#  717: 'mobile apps',
#  718: 'mobile apps',
#  719: 'mobile apps',
#  720: 'mobile apps',
#  721: 'mobile apps',
#  722: 'mobile apps',
#  723: 'mobile apps',
#  724: 'mobile apps',
#  725: 'mobile apps',
#  726: 'mobile apps',
#  727: 'mobile apps',
#  728: 'mobile apps',
#  729: 'mobile apps',
#  730: 'mobile apps',
#  731: 'mobile apps',
#  732: 'mobile apps',
#  733: 'mobile apps',
#  734: 'mobile apps',
#  735: 'mobile apps',
#  736: 'mobile apps',
#  737: 'mobile apps',
#  738: 'mobile apps',
#  739: 'mobile apps',
#  740: 'mobile apps',
#  741: 'mobile apps',
#  742: 'mobile apps',
#  743: 'mobile apps',
#  744: 'mobile apps',
#  745: 'mobile apps',
#  746: 'mobile apps',
#  747: 'mobile apps',
#  748: 'mobile apps',
#  749: 'mobile apps',
#  750: 'mobile apps',
#  751: 'mobile apps',
#  752: 'mobile apps',
#  753: 'mobile apps',
#  754: 'mobile apps',
#  755: 'mobile apps',
#  756: 'mobile apps',
#  757: 'mobile apps',
#  758: 'mobile apps',
#  759: 'mobile apps',
#  760: 'mobile apps',
#  761: 'mobile apps',
#  762: 'mobile apps',
#  763: 'mobile apps',
#  764: 'mobile apps',
#  765: 'mobile apps',
#  766: 'mobile apps',
#  767: 'mobile apps',
#  768: 'mobile apps',
#  769: 'mobile apps',
#  770: 'mobile apps',
#  771: 'mobile apps',
#  772: 'mobile apps',
#  773: 'mobile apps',
#  774: 'mobile apps',
#  775: 'mobile apps',
#  776: 'mobile apps',
#  777: 'mobile apps',
#  778: 'mobile apps',
#  779: 'mobile apps',
#  780: 'mobile apps',
#  781: 'mobile apps',
#  782: 'mobile apps',
#  783: 'mobile apps',
#  784: 'mobile apps',
#  785: 'mobile apps',
#  786: 'mobile apps',
#  787: 'mobile apps',
#  788: 'mobile apps',
#  789: 'mobile apps',
#  790: 'mobile apps',
#  791: 'mobile apps',
#  792: 'mobile apps',
#  793: 'mobile apps',
#  794: 'mobile apps',
#  795: 'mobile apps',
#  796: 'mobile apps',
#  797: 'mobile apps',
#  798: 'mobile apps',
#  799: 'mobile apps',
#  800: 'mobile apps',
#  801: 'mobile apps',
#  802: 'mobile apps',
#  803: 'mobile apps',
#  804: 'mobile apps',
#  805: 'mobile apps',
#  806: 'mobile apps',
#  807: 'mobile apps',
#  808: 'mobile apps',
#  809: 'mobile apps',
#  810: 'mobile apps',
#  811: 'mobile apps',
#  812: 'mobile apps',
#  813: 'mobile apps',
#  814: 'mobile apps',
#  815: 'mobile apps',
#  816: 'mobile apps',
#  817: 'mobile apps',
#  818: 'mobile apps',
#  819: 'mobile apps',
#  820: 'mobile apps',
#  821: 'mobile apps',
#  822: 'mobile apps',
#  823: 'mobile apps',
#  824: 'mobile apps',
#  825: 'mobile apps',
#  826: 'mobile apps',
#  827: 'mobile apps',
#  828: 'mobile apps',
#  829: 'mobile apps',
#  830: 'mobile apps',
#  831: 'mobile apps',
#  832: 'mobile apps',
#  833: 'mobile apps',
#  834: 'mobile apps',
#  835: 'mobile apps',
#  836: 'mobile apps',
#  837: 'mobile apps',
#  838: 'mobile apps',
#  839: 'mobile apps',
#  840: 'mobile apps',
#  841: 'mobile apps',
#  842: 'mobile apps',
#  843: 'mobile apps',
#  844: 'mobile apps',
#  845: 'mobile apps',
#  846: 'mobile apps',
#  847: 'mobile apps',
#  848: 'mobile apps',
#  849: 'mobile apps',
#  850: 'mobile apps',
#  851: 'mobile apps',
#  852: 'mobile apps',
#  853: 'mobile apps',
#  854: 'mobile apps',
#  855: 'mobile apps',
#  856: 'mobile apps',
#  857: 'mobile apps',
#  858: 'mobile apps',
#  859: 'mobile apps',
#  860: 'mobile apps',
#  861: 'mobile apps',
#  862: 'mobile apps',
#  863: 'mobile apps',
#  864: 'mobile apps',
#  865: 'mobile apps',
#  866: 'mobile apps',
#  867: 'mobile apps',
#  868: 'mobile apps',
#  869: 'mobile apps',
#  870: 'wordpress, rails, javascript, ruby',
#  871: 'wordpress, rails, javascript, ruby',
#  872: 'wordpress, rails, javascript, ruby',
#  873: 'wordpress, rails, javascript, ruby',
#  874: 'wordpress, rails, javascript, ruby',
#  875: 'wordpress, rails, javascript, ruby',
#  876: 'wordpress, rails, javascript, ruby',
#  877: 'wordpress, rails, javascript, ruby',
#  878: 'wordpress, rails, javascript, ruby',
#  879: 'wordpress, rails, javascript, ruby',
#  880: 'wordpress, rails, javascript, ruby',
#  881: 'wordpress, rails, javascript, ruby',
#  882: 'wordpress, rails, javascript, ruby',
#  883: 'wordpress, rails, javascript, ruby',
#  884: 'wordpress, rails, javascript, ruby',
#  885: 'wordpress, rails, javascript, ruby',
#  886: 'wordpress, rails, javascript, ruby',
#  887: 'wordpress, rails, javascript, ruby',
#  888: 'wordpress, rails, javascript, ruby',
#  889: 'wordpress, rails, javascript, ruby',
#  890: 'wordpress, rails, javascript, ruby',
#  891: 'wordpress, rails, javascript, ruby',
#  892: 'wordpress, rails, javascript, ruby',
#  893: 'wordpress, rails, javascript, ruby',
#  894: 'wordpress, rails, javascript, ruby',
#  895: 'wordpress, rails, javascript, ruby',
#  896: 'wordpress, rails, javascript, ruby',
#  897: 'wordpress, rails, javascript, ruby',
#  898: 'wordpress, rails, javascript, ruby',
#  899: 'wordpress, rails, javascript, ruby',
#  900: 'wordpress, rails, javascript, ruby',
#  901: 'wordpress, rails, javascript, ruby',
#  902: 'wordpress, rails, javascript, ruby',
#  903: 'wordpress, rails, javascript, ruby',
#  904: 'wordpress, rails, javascript, ruby',
#  905: 'wordpress, rails, javascript, ruby',
#  906: 'wordpress, rails, javascript, ruby',
#  907: 'wordpress, rails, javascript, ruby',
#  908: 'wordpress, rails, javascript, ruby',
#  909: 'wordpress, rails, javascript, ruby',
#  910: 'wordpress, rails, javascript, ruby',
#  911: 'wordpress, rails, javascript, ruby',
#  912: 'wordpress, rails, javascript, ruby',
#  913: 'wordpress, rails, javascript, ruby',
#  914: 'wordpress, rails, javascript, ruby',
#  915: 'wordpress, rails, javascript, ruby',
#  916: 'wordpress, rails, javascript, ruby',
#  917: 'wordpress, rails, javascript, ruby',
#  918: 'wordpress, rails, javascript, ruby',
#  919: 'wordpress, rails, javascript, ruby',
#  920: 'wordpress, rails, javascript, ruby',
#  921: 'wordpress, rails, javascript, ruby',
#  922: 'wordpress, rails, javascript, ruby',
#  923: 'wordpress, rails, javascript, ruby',
#  924: 'wordpress, rails, javascript, ruby',
#  925: 'wordpress, rails, javascript, ruby',
#  926: 'wordpress, rails, javascript, ruby',
#  927: 'wordpress, rails, javascript, ruby',
#  928: 'wordpress, rails, javascript, ruby',
#  929: 'wordpress, rails, javascript, ruby',
#  930: 'wordpress, rails, javascript, ruby',
#  931: 'wordpress, rails, javascript, ruby',
#  932: 'wordpress, rails, javascript, ruby',
#  933: 'wordpress, rails, javascript, ruby',
#  934: 'wordpress, rails, javascript, ruby',
#  935: 'wordpress, rails, javascript, ruby',
#  936: 'wordpress, rails, javascript, ruby',
#  937: 'wordpress, rails, javascript, ruby',
#  938: 'wordpress, rails, javascript, ruby',
#  939: 'wordpress, rails, javascript, ruby',
#  940: 'wordpress, rails, javascript, ruby',
#  941: 'wordpress, rails, javascript, ruby',
#  942: 'wordpress, rails, javascript, ruby',
#  943: 'wordpress, rails, javascript, ruby',
#  944: 'wordpress, rails, javascript, ruby',
#  945: 'wordpress, rails, javascript, ruby',
#  946: 'wordpress, rails, javascript, ruby',
#  947: 'wordpress, rails, javascript, ruby',
#  948: 'wordpress, rails, javascript, ruby',
#  949: 'wordpress, rails, javascript, ruby',
#  950: 'wordpress, rails, javascript, ruby',
#  951: 'wordpress, rails, javascript, ruby',
#  952: 'wordpress, rails, javascript, ruby',
#  953: 'wordpress, rails, javascript, ruby',
#  954: 'wordpress, rails, javascript, ruby',
#  955: 'wordpress, rails, javascript, ruby',
#  956: 'wordpress, rails, javascript, ruby',
#  957: 'wordpress, rails, javascript, ruby',
#  958: 'wordpress, rails, javascript, ruby',
#  959: 'wordpress, rails, javascript, ruby',
#  960: 'wordpress, rails, javascript, ruby',
#  961: 'wordpress, rails, javascript, ruby',
#  962: 'wordpress, rails, javascript, ruby',
#  963: 'wordpress, rails, javascript, ruby',
#  964: 'wordpress, rails, javascript, ruby',
#  965: 'wordpress, rails, javascript, ruby',
#  966: 'wordpress, rails, javascript, ruby',
#  967: 'wordpress, rails, javascript, ruby',
#  968: 'wordpress, rails, javascript, ruby',
#  969: 'wordpress, rails, javascript, ruby',
#  970: 'wordpress, rails, javascript, ruby',
#  971: 'wordpress, rails, javascript, ruby',
#  972: 'wordpress, rails, javascript, ruby',
#  973: 'wordpress, rails, javascript, ruby',
#  974: 'wordpress, rails, javascript, ruby',
#  975: 'wordpress, rails, javascript, ruby',
#  976: 'wordpress, rails, javascript, ruby',
#  977: 'wordpress, rails, javascript, ruby',
#  978: 'wordpress, rails, javascript, ruby',
#  979: 'wordpress, rails, javascript, ruby',
#  980: 'wordpress, rails, javascript, ruby',
#  981: 'wordpress, rails, javascript, ruby',
#  982: 'wordpress, rails, javascript, ruby',
#  983: 'wordpress, rails, javascript, ruby',
#  984: 'wordpress, rails, javascript, ruby',
#  985: 'wordpress, rails, javascript, ruby',
#  986: 'wordpress, rails, javascript, ruby',
#  987: 'wordpress, rails, javascript, ruby',
#  988: 'wordpress, rails, javascript, ruby',
#  989: 'wordpress, rails, javascript, ruby',
#  990: 'wordpress, rails, javascript, ruby',
#  991: 'wordpress, rails, javascript, ruby',
#  992: 'wordpress, rails, javascript, ruby',
#  993: 'wordpress, rails, javascript, ruby',
#  994: 'wordpress, rails, javascript, ruby',
#  995: 'wordpress, rails, javascript, ruby',
#  996: 'wordpress, rails, javascript, ruby',
#  997: 'wordpress, rails, javascript, ruby',
#  998: 'wordpress, rails, javascript, ruby',
#  999: 'wordpress, rails, javascript, ruby',
#  ...}

# %%
len(title_category)
# Out:
# 47583

# %%
df["title_category_nmf"] = title_category.values()

# %%
df.tail()
# Out:
#         Unnamed: 0       _class_x  \
# 337071      337072  course_review
# 337091      337092  course_review
# 337096      337097  course_review
# 337126      337127  course_review
# 337138      337139  course_review
#
#                                                   content  course_id  \
# 337071  This course was great!  Never heard of anyone ...     851826
# 337091  This course provides a great introduction to c...     281692
# 337096  I find the instructor easy to listen to as he ...     847460
# 337126  Thank you very much for sharing these awesome ...     640408
# 337138  I feel that I have been taken on a journey tow...     537750
#
#                      created       id              modified  rating  \
# 337071  2016-05-27T15:34:27Z  2281140  2016-05-27T15:34:27Z     5.0
# 337091  2014-11-14T11:31:20Z   234800  2014-11-14T11:31:20Z     5.0
# 337096  2016-06-03T02:38:12Z  2356902  2016-06-18T09:00:30Z     5.0
# 337126  2015-10-16T04:35:56Z   725148  2015-10-16T04:35:56Z     5.0
# 337138  2015-06-30T09:11:28Z   446584  2015-06-30T09:11:28Z     5.0
#
#                                                   title_x  \
# 337071                                                NaN
# 337091  A great starting point for making Youtube vide...
# 337096                                                NaN
# 337126                                    Amazing course!
# 337138  Inspirational!A supreme guide to setting and a...
#
#                                                      user  \
# 337071  {u'_class': u'user', u'display_name': u'Suzann...
# 337091  {u'_class': u'user', u'display_name': u'Kennet...
# 337096  {u'_class': u'user', u'display_name': u'Rudolf...
# 337126  {u'_class': u'user', u'display_name': u'Vaness...
# 337138  {u'_class': u'user', u'display_name': u'Katarz...
#
#                        ...                  user_review_count  \
# 337071                 ...                                  3
# 337091                 ...                                  5
# 337096                 ...                                  3
# 337126                 ...                                  3
# 337138                 ...                                  3
#
#        course_review_count course_rating_avg       instructor_name  \
# 337071                  20              4.50   u'James Canzanella'
# 337091                   5              5.00        u'Robert Scot'
# 337096                   3              5.00       u'Diego Davila'
# 337126                   4              4.25        u'Sandor Kiss'
# 337138                   1              5.00      u'Jimmy Naraine'
#
#                                          instructor_title  new_course_id  \
# 337071                 u'Utterly Simple Online Profits'}]            728
# 337091   u'Dr YouTube is a multi-media Marketing Exper...            194
# 337096                           u'Your Online Academy'}]            724
# 337126                                     u'Entrepreneur            521
# 337138          u'Winner of Udemy's Innovation Award & 78            422
#
#         new_user_id                            course_category  Unnamed: 35  \
# 337071        16590                                        art          NaN
# 337091        13240                                   business          NaN
# 337096        59860  software development / mobile application          NaN
# 337126        86326                                   business          NaN
# 337138        54379                                   business          NaN
#
#                         title_category_nmf
# 337071  wordpress, rails, javascript, ruby
# 337091  wordpress, rails, javascript, ruby
# 337096   web design - html, css, wordpress
# 337126                         mobile apps
# 337138                    java programming
#
# [5 rows x 37 columns]

# %%
df.to_csv("reg_nmf.csv")
